# %%
import os
if os.getcwd().endswith("Misc Fig and Table Generation Scripts"):
    os.chdir('../')

from cdrift.utils.helpers import import_test_results
from cdrift import evaluation
import matplotlib.pyplot as plt

# %%
for base_dir in ["testAll", "testAll_Noisy", "testAll_ApproachLogs"]:
    dfs = import_test_results(base_dir)
    evaluation.scatter_f1_duration(dfs)
